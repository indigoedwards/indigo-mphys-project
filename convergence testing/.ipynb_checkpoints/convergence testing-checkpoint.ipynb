# %% [markdown]
# First define universal stuff

# %%
import numpy as np
import iDEA as idea
import matplotlib.pyplot as plt

# %% [markdown]
# Convergance testing for x grid points:

# %%
xtestspace = np.linspace(25,500,20).astype(int)
print(xtestspace)

energies=[]
for xnumber in xtestspace:
    x = np.linspace(-30,30,xnumber)
    v_int = idea.interactions.softened_interaction(x)
    v_ext = -2*np.exp(-((x-20)**2)/10) - 2.005*np.exp(-((x+20)**2)/10) #gaussians
    
    system = idea.system.System(x,v_ext,v_int,electrons="uu")
    system_firststate = idea.methods.interacting.solve(system, k=1)
                                                      
    charge_density = idea.observables.density(system, state=system_firststate)
    hartree_potential = idea.observables.hartree_potential(system, charge_density)
    energies.append(idea.observables.hartree_energy(system, charge_density, hartree_potential))
# Out:
# [ 25  50  75 100 125 150 175 200 225 250 275 300 325 350 375 400 425 450
#  475 500]
# iDEA.methods.interacting.solve: solving eigenproblem...
# iDEA.methods.interacting.solve: solving eigenproblem...
# iDEA.methods.interacting.solve: solving eigenproblem...
# iDEA.methods.interacting.solve: solving eigenproblem...
# iDEA.methods.interacting.solve: solving eigenproblem...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 11
#       8 v_ext = -2*np.exp(-((x-20)**2)/10) - 2.005*np.exp(-((x+20)**2)/10) #gaussians
#      10 system = idea.system.System(x,v_ext,v_int,electrons="uu")
# ---> 11 system_firststate = idea.methods.interacting.solve(system, k=1)
#      13 charge_density = idea.observables.density(system, state=system_firststate)
#      14 hartree_potential = idea.observables.hartree_potential(system, charge_density)
#
# File C:\ProgramData\anaconda3\envs\mphys\Lib\site-packages\iDEA\methods\interacting.py:329, in solve(s, H, k, level)
#     327     spaces = spaces.get()
#     328 else:
# --> 329     energies, spaces = spsla.eigsh(H.tocsr(), k=level, which="SA")
#     331 # Reshape and normalise the solutions.
#     332 spaces = spaces.reshape((s.x.shape[0],) * s.count + (spaces.shape[-1],))
#
# File C:\ProgramData\anaconda3\envs\mphys\Lib\site-packages\scipy\sparse\linalg\_eigen\arpack\arpack.py:1700, in eigsh(A, k, M, sigma, which, v0, ncv, maxiter, tol, return_eigenvectors, Minv, OPinv, mode)
#    1698 with _ARPACK_LOCK:
#    1699     while not params.converged:
# -> 1700         params.iterate()
#    1702     return params.extract(return_eigenvectors)
#
# File C:\ProgramData\anaconda3\envs\mphys\Lib\site-packages\scipy\sparse\linalg\_eigen\arpack\arpack.py:537, in _SymmetricArpackParams.iterate(self)
#     535 def iterate(self):
#     536     self.ido, self.tol, self.resid, self.v, self.iparam, self.ipntr, self.info = \
# --> 537         self._arpack_solver(self.ido, self.bmat, self.which, self.k,
#     538                             self.tol, self.resid, self.v, self.iparam,
#     539                             self.ipntr, self.workd, self.workl, self.info)
#     541     xslice = slice(self.ipntr[0] - 1, self.ipntr[0] - 1 + self.n)
#     542     yslice = slice(self.ipntr[1] - 1, self.ipntr[1] - 1 + self.n)
#
# KeyboardInterrupt:

# %%
plt.plot(xtestspace,energies)
plt.show()
plt.close()

plt.plot(xtestspace, np.log10(energies-energies[-1]))
plt.show()
# Out:
# C:\Users\Iansyst Loan\AppData\Local\Temp\ipykernel_6844\120183274.py:1: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(xtestspace, np.log10(energies-energies[-1]))
